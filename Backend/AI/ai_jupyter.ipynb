# %%
# !pip install python-dotenv
# !pip install -U sentence-transformers
# !pip install bitsandbytes
# !pip install accelerate
# !pip install chromadb
# !pip install huggingface_hub
# !pip install peft
# !pip install -q -U einops
# !pip install -q -U safetensors
# !pip install -q -U torch
# !pip install -q -U xformers
# !pip -q install langchain
# !pip -q install bitsandbytes accelerate xformers einops
# !pip -q install datasets loralib sentencepiece
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers)
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece (from sentence-transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.1 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.17.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 34.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.3 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.5 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=889aeb553ad9de552114588c2ea337fa3e171d30d605f678dde0987cf3fc4329
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, safetensors, huggingface-hub, transformers, sentence-transformers
# Successfully installed huggingface-hub-0.17.2 safetensors-0.3.3 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.33.2
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.41.1-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 1.9 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.41.1
# Collecting accelerate
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.1+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.17.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (16.0.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.23.0
# Collecting chromadb
#   Downloading chromadb-0.4.12-py3-none-any.whl (426 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.5/426.5 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic<2.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.10.12)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 61.6 MB/s eta 0:00:00
# Collecting fastapi<0.100.0,>=0.95.2 (from chromadb)
#   Downloading fastapi-0.99.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.8 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 6.8 MB/s eta 0:00:00
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.5.0)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 71.9 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 92.7 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.13.3)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 8.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 44.7 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.9.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.23.5)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi<0.100.0,>=0.95.2->chromadb)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.3 MB/s eta 0:00:00
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (23.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pulsar-client>=3.1.0->chromadb) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.2 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (428 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 kB 46.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 101.4 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.1 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (3.7.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.1.3)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=c1da59abae15707c83119845b637f2e0e61aa32361ab293ee76c3098e18e92db
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, websockets, uvloop, pulsar-client, overrides, humanfriendly, httptools, h11, chroma-hnswlib, bcrypt, backoff, watchfiles, uvicorn, starlette, posthog, coloredlogs, onnxruntime, fastapi, chromadb
# Successfully installed backoff-2.2.1 bcrypt-4.0.1 chroma-hnswlib-0.7.3 chromadb-0.4.12 coloredlogs-15.0.1 fastapi-0.99.1 h11-0.14.0 httptools-0.6.0 humanfriendly-10.0 monotonic-1.6 onnxruntime-1.16.0 overrides-7.4.0 posthog-3.0.2 pulsar-client-3.3.0 pypika-0.48.9 starlette-0.27.0 uvicorn-0.23.2 uvloop-0.17.0 watchfiles-0.20.0 websockets-11.0.3
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.17.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)
# Collecting peft
#   Downloading peft-0.5.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.0.1+cu118)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft) (4.33.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft) (4.66.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from peft) (0.23.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft) (0.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->peft) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->peft) (16.0.6)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate->peft) (0.17.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (0.13.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate->peft) (2023.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Installing collected packages: peft
# Successfully installed peft-0.5.0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.0/167.0 MB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.7 MB/s eta 0:00:00

# %%
#imports
import sys
import chromadb
import torch
import transformers
import warnings
import torch
import os
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import pipeline
from langchain import HuggingFacePipeline, PromptTemplate
from langchain.chains import RetrievalQA
from langchain.vectorstores import Chroma
from dotenv import load_dotenv
from langchain.llms import HuggingFaceHub
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Pinecone
from langchain.embeddings import SentenceTransformerEmbeddings
from huggingface_hub import notebook_login
from langchain.chains import RetrievalQA
from huggingface_hub import notebook_login
from transformers import AutoTokenizer, AutoModelForCausalLM
from huggingface_hub import login
warnings.filterwarnings('ignore')

# %%
# notebook_login()

#Logging into hugginngFace
os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"
login(token=os.environ.get("HUGGINGFACEHUB_API_TOKEN"))
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
#load expertises
import pandas as pd
csv = pd.read_csv("/content/cleaned_expertise.csv", usecols =
 [
    "ID",
    "4. Veuillez indiquer à quelle catégorie de membres vous identifiez-vous : ",
    "4.1. Veuillez préciser quel autre catégorie de membres si applicable: ",
    "5. Veuillez préciser votre titre d'emploi: (ex: pour les chercheurs indiquer si régulier, postdoctoral ou autre, pour les étudiants indiquer le niveau d'études, si industriels/professionnels de recherche indiquer le poste d'emploi)",
    "6. Veuillez indiquer votre organisation d'affiliation: ",
    "6.1. Veuillez préciser quel autre organisation d'affiliation si applicable: ",
    "7. Veuillez décrire brièvement vos compétences ou votre expertise:",
    "7.1. Veuillez indiquer le nombre d'années d'expérience (professionnelle/études) en IA: ",
    "7.2. Veuillez indiquer le nombre d'années d'expérience (professionnelle/études) en santé: ",
    "Prénom",
    "Nom"
  ] )

csv.rename(columns=
 {
  "ID": "ID: ",
  "4. Veuillez indiquer à quelle catégorie de membres vous identifiez-vous : ": "Profession: ",
  "4.1. Veuillez préciser quel autre catégorie de membres si applicable: ": "Autre profession: ",
  "5. Veuillez préciser votre titre d'emploi: (ex: pour les chercheurs indiquer si régulier, postdoctoral ou autre, pour les étudiants indiquer le niveau d'études, si industriels/professionnels de recherche indiquer le poste d'emploi)": "Titre d'emploi: ",
  "6. Veuillez indiquer votre organisation d'affiliation: ": "Organisation d'affiliation: ",
  "6.1. Veuillez préciser quel autre organisation d'affiliation si applicable: ": "Autre organisation d'affiliation: ",
  "7. Veuillez décrire brièvement vos compétences ou votre expertise:": "Expertises: ",
  "7.1. Veuillez indiquer le nombre d'années d'expérience (professionnelle/études) en IA: ": "Années d'expérience en intelligence artificielle: ",
  "7.2. Veuillez indiquer le nombre d'années d'expérience (professionnelle/études) en santé: ": "Années d'expérience en santé: ",
  "Prénom": "Prénom: ",
  "Nom": "Nom: "
  }
  , inplace=True)
expertises = []
count = 0
for index, row in csv.iterrows():
    count += 1
    column_values = []
    for column, value in row.items():
        column_value_str = f'{column}{value}'
        column_values.append(column_value_str)

    row_str = '\n'.join(column_values)
    expertises.append(row_str)

for x in expertises:
  print("#####################################")
  print(x)
  print("#####################################")
# Out:
# #####################################
# ID: 1
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: Post doc
# Organisation d'affiliation: TÉLUQ-Université TÉLUQ
# Autre organisation d'affiliation: nan
# Expertises: Application de l'IA  sur les données en santé
# Années d'expérience en intelligence artificielle: 5.0
# Années d'expérience en santé: 5.0
# #####################################
# #####################################
# ID: 2
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: Docteure
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: nan
# Expertises: Calcul haute performace et algèbre linéaire numérique
# Années d'expérience en intelligence artificielle: 2.0
# Années d'expérience en santé: 2.0
# #####################################
# #####################################
# ID: 3
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: Ph.D.
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, IVADO- Institut de Valorisation des Données, UDEM- Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Intelligence artificielle et neurosciences
# Années d'expérience en intelligence artificielle: 9.0
# Années d'expérience en santé: 13.0
# #####################################
# #####################################
# ID: 4
# Prénom: nan
# Nom: nan
# Profession: /
# Autre profession: nan
# Titre d'emploi: Coordonnateur de recherche
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Statistiques, bases de données, recherche clinique
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 10.0
# #####################################
# #####################################
# ID: 5
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: Doctorat
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, Polytechnique Montréal
# Autre organisation d'affiliation: nan
# Expertises: Apprentissage machine et profond en neurosciences
# Années d'expérience en intelligence artificielle: 4.0
# Années d'expérience en santé: 4.0
# #####################################
# #####################################
# ID: 6
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: UETMIS
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Implantation des technologies IA
# Années d'expérience en intelligence artificielle: 3.0
# Années d'expérience en santé: 10.0
# #####################################
# #####################################
# ID: 7
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: Régulier /Professeur
# Organisation d'affiliation: CRCHUSJ- Centre de Recherche du Centre Hospitalier de Sainte Justine
# Autre organisation d'affiliation: nan
# Expertises: IA à partir de capteurs physiologiques/mouvement humain
# Années d'expérience en intelligence artificielle: 4.0
# Années d'expérience en santé: 12.0
# #####################################
# #####################################
# ID: 8
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Assistante de recherche/Enseignante
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, TÉLUQ- Université TÉLUQ
# Autre organisation d'affiliation: nan
# Expertises: Apprentissage statistique/machine
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 3.0
# #####################################
# #####################################
# ID: 9
# Prénom: nan
# Nom: nan
# Profession: Industriels
# Autre profession: nan
# Titre d'emploi: Directrice Stratégie & Innovation
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: Logibec
# Expertises: Transformation numérique et IA
# Années d'expérience en intelligence artificielle: 5.0
# Années d'expérience en santé: 15.0
# #####################################
# #####################################
# ID: 10
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: Maîtrise
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, Polytechnique Montréal
# Autre organisation d'affiliation: nan
# Expertises: Apprentissage profond sur les images médicales et histopathologiques
# Années d'expérience en intelligence artificielle: 3.0
# Années d'expérience en santé: 5.0
# #####################################
# #####################################
# ID: 11
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: Gestionnaire
# Titre d'emploi: nan
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Éthique et Gestion
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 10.0
# #####################################
# #####################################
# ID: 12
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Analyste informatique
# Titre d'emploi: Analyste informatique
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Bio-informatique, NGS, Data science
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 3.0
# #####################################
# #####################################
# ID: 13
# Prénom: nan
# Nom: nan
# Profession: Industriels
# Autre profession: nan
# Titre d'emploi: Analyste en intelligence d'affaire
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: SCT
# Expertises: Étudiante en IA
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 0.0
# #####################################
# #####################################
# ID: 14
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Directeur intérimaire
# Titre d'emploi: Directeur intérimaire
# Organisation d'affiliation: MSSS- Ministère de la Santé et des Services Sociaux
# Autre organisation d'affiliation: nan
# Expertises: Gestion
# Années d'expérience en intelligence artificielle: 5.0
# Années d'expérience en santé: 30.0
# #####################################
# #####################################
# ID: 15
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Conseiller Principal de Recherche
# Organisation d'affiliation: Consortium Santé Numérique, IVADO- Institut de Valorisation des Données, UDEM- Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Machine learning & génomique
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 6.0
# #####################################
# #####################################
# ID: 16
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Biostatisticienne
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Biostatistique, prédiction, recherche clinique
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 8.0
# #####################################
# #####################################
# ID: 17
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Programmeur analyste
# Titre d'emploi: Programmeur analyste
# Organisation d'affiliation: Université d'Ottawa
# Autre organisation d'affiliation: nan
# Expertises: Étudiant en IA
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 0.0
# #####################################
# #####################################
# ID: 18
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Conseiller principal de recherche
# Organisation d'affiliation: Consortium Santé Numérique, UDEM- Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Sciences des données de santé, psychiatrie computationnelle
# Années d'expérience en intelligence artificielle: 5.0
# Années d'expérience en santé: 10.0
# #####################################
# #####################################
# ID: 19
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Conseillère Principal de Recherche
# Organisation d'affiliation: Plateforme IA-Agrosanté, UDEM- Université de Montréal, FMV- Faculté de Médecine Vétérinaire
# Autre organisation d'affiliation: nan
# Expertises: statistique, BD, Machine learning
# Années d'expérience en intelligence artificielle: 6.0
# Années d'expérience en santé: 12.0
# #####################################
# #####################################
# ID: 20
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Conseillère Principale de Recherche
# Organisation d'affiliation: Plateforme IA-Agrosanté, UDEM- Université de Montréal, FMV- Faculté de Médecine Vétérinaire
# Autre organisation d'affiliation: nan
# Expertises: IA, Machine Learning, cloud, data
# Années d'expérience en intelligence artificielle: 7.0
# Années d'expérience en santé: 1.0
# #####################################
# #####################################
# ID: 21
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: Maîtrise
# Organisation d'affiliation: LIO- Laboratoire de recherche en Imagerie et Orthopédie
# Autre organisation d'affiliation: nan
# Expertises: Ingénierie générale
# Années d'expérience en intelligence artificielle: 2.0
# Années d'expérience en santé: 2.0
# #####################################
# #####################################
# ID: 22
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: post-doctorante
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, UDEM- Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Imagerie cardiovasculaire (échocardiographie), maladie cardiaque (maladie valvulaire, amyloïdose)
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 8.0
# #####################################
# #####################################
# ID: 23
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: postdoctorant
# Organisation d'affiliation: LIO- Laboratoire de recherche en Imagerie et Orthopédie
# Autre organisation d'affiliation: nan
# Expertises: je travaille en IA depuis quelques mois. Mes projets et domaines d' application sont centrés sur l' imagerie médicale (classification, segmentation).
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 6.0
# #####################################
# #####################################
# ID: 25
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: Chercheurs
# Titre d'emploi: Etudiant MD
# Organisation d'affiliation: UDEM- Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Maitrise en Informatique, habilités de programmation
# Années d'expérience en intelligence artificielle: 3.0
# Années d'expérience en santé: 1.0
# #####################################
# #####################################
# ID: 26
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: Maîtrise
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Détection de crises épiletpqieus
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 5.0
# #####################################
# #####################################
# ID: 28
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Coordonnateur de programme en science des données médicales
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Bio-informatique, science des données, génomique
# Années d'expérience en intelligence artificielle: 4.0
# Années d'expérience en santé: 16.0
# #####################################
# #####################################
# ID: 29
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: Étudiant en 3e année de médecine
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, UDEM- Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Connaissances intermédiaires en machine learning
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 3.0
# #####################################
# #####################################
# ID: 30
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Gestionnaire dans le Réseau de la santé
# Titre d'emploi: cosneillère cadre en gestion des ressources matérielles
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: CHUM
# Expertises: débutante
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 35.0
# #####################################
# #####################################
# ID: 31
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Pédagogie
# Titre d'emploi: Conseillère en apprentissage - technopédagogue
# Organisation d'affiliation: ÉIAS- École de l'Intelligence Artificielle en Santé
# Autre organisation d'affiliation: Société canadienne du cancer
# Expertises: Pédagogie, transformation numérique, création de formations, eLearning
# Années d'expérience en intelligence artificielle: nan
# Années d'expérience en santé: nan
# #####################################
# #####################################
# ID: 32
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: co-chercheur CRCHUM et conseiller en innovation pôle d'Innovation et d'IA (DG)
# Titre d'emploi: co-chercheur CRCHUM et conseiller en innovation pôle d'Innovation et d'IA (DG)
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: CHUM
# Expertises: Débutant en IA (connaissances plutôt théoriques, mais non pratiques). Bonne maîtrise des approches de gestion de projet, design collaboratif, innovation en santé. Recherche qualitative, rédaction scientifique, animation.
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 5.0
# #####################################
# #####################################
# ID: 33
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: Étudiant en médecine (5e année)
# Organisation d'affiliation: CRCHUSJ- Centre de Recherche du Centre Hospitalier de Sainte Justine, Autre
# Autre organisation d'affiliation: Faculté de santé d'Angers (France)
# Expertises: Néophyte en informatique (compétences de base en programmation (Python, R))
# Fort intérêt pour le sujet néanmoins
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 5.0
# #####################################
# #####################################
# ID: 34
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Coordonnatrice de recherche
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, Autre
# Autre organisation d'affiliation: Chaire de recherche sur les nouvelles pratiques de soins infirmiers
# Expertises: Expertise au niveau de la conception et évaluation d'interventions numérique en santé (sites web; application mobile). Intéressée par l'intégration de l'IA dans ce type de projet (mais aucune expérience à ce jour).
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 13.0
# #####################################
# #####################################
# ID: 35
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: Associé de recherche
# Organisation d'affiliation: LIO- Laboratoire de recherche en Imagerie et Orthopédie
# Autre organisation d'affiliation: nan
# Expertises: Traitement d'images, reconstruction 3D, Apprentissage machine
# Années d'expérience en intelligence artificielle: nan
# Années d'expérience en santé: nan
# #####################################
# #####################################
# ID: 36
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: conseiller en innovation
# Titre d'emploi: conseiller en innovation DEAC (ÉIAS)
# Organisation d'affiliation: ÉIAS- École de l'Intelligence Artificielle en Santé
# Autre organisation d'affiliation: CRCHUM
# Expertises: innovation, gestion du changement, développement organisationnel, gestion de projet, recherche qualitative
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 3.0
# #####################################
# #####################################
# ID: 37
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: Phd
# Organisation d'affiliation: LIO- Laboratoire de recherche en Imagerie et Orthopédie, ÉTS- École de Technologie Supérieure
# Autre organisation d'affiliation: nan
# Expertises: Master en informatique, spécialité reconnaissance des formes et intelligence artificielle.
# Sujet de doctorat: Calibration d'un système de stéréoradiographie. Classification d'images EOS. Je travaille depuis presque un an sur des méthode d'apprentissage profond.
# Années d'expérience en intelligence artificielle: 3.0
# Années d'expérience en santé: 5.0
# #####################################
# #####################################
# ID: 38
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: Clinician-Scientist
# Titre d'emploi: Full time Assistant Professor, Department of Pediatrics, Division of Pediatric Endocrinology and Metabolism
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: McGill University Health Center Research institute
# Expertises: I am a new clinician-scientist developing my research program on the use of machine learning to address crucial clinical questions in the field of pediatric diabetes
# Années d'expérience en intelligence artificielle: nan
# Années d'expérience en santé: nan
# #####################################
# #####################################
# ID: 39
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: Étudiant PhD, chercheur CRCHUM, professionnel de la santé
# Titre d'emploi: chercheur régulier, étudiant PhD
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, CHUM- Centre Hospitalier de l'Université de Montréal, UDEM- Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Infirmier praticien spécialisé en cardiologie
# Années d'expérience en intelligence artificielle: 2.0
# Années d'expérience en santé: 11.0
# #####################################
# #####################################
# ID: 40
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Professionnel de la santé
# Titre d'emploi: Conseiller en soins infirmiers
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: CCSMTL-DADRI
# Expertises: Soins critiques, soins infirmiers, informatisation clinique, pilotage applicatif
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 11.0
# #####################################
# #####################################
# ID: 41
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: Médecin
# Titre d'emploi: Gynéco oncologie
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: recherche clinique et translationnelle + clinicien
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 30.0
# #####################################
# #####################################
# ID: 42
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Agente de recherche et Agente de liaison Q-CRCO
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: AEC informations / develop base de donnée et powerBI
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 0.0
# #####################################
# #####################################
# ID: 43
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: Industriels
# Titre d'emploi: Professeur Polytechnique, Chercheur CRCHUM
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: Polytechnique Montreal
# Expertises: Instrumentation optique, Métrologie, Tomographie, Apprentissage machine, Chirurgie, Pathologie
# Années d'expérience en intelligence artificielle: 5.0
# Années d'expérience en santé: 15.0
# #####################################
# #####################################
# ID: 44
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: associé de recherche
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, Polytechnique Montréal
# Autre organisation d'affiliation: LRO - Laboratoire de radiologie optique
# Expertises: ingénierie, imagerie optique
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 2.0
# #####################################
# #####################################
# ID: 60
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Associé de recherche
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, Polytechnique Montréal
# Autre organisation d'affiliation: nan
# Expertises: Apprentissage profond (deep learning) pour imagerie medicale (radiologie, radio-oncologie)
# Années d'expérience en intelligence artificielle: 3.0
# Années d'expérience en santé: 3.0
# #####################################
# #####################################
# ID: 61
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Scientifique de l'IA [PhD]
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: Institut Intelligence et Données - Université Laval
# Expertises: Scientifique de l'IA depuis la définition stratégique jusqu'à la mise en oeuvre pratique.
# Années d'expérience en intelligence artificielle: 18.0
# Années d'expérience en santé: 0.5
# #####################################
# #####################################
# ID: 62
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: Je suis aussi consultant en intégration de données
# Titre d'emploi: nan
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: Université Laval
# Expertises: Intégration de données, logiciels libres, science des données, implication citoyenne, actuariat et assurances, macroéconomie, formation/accompagnement.
# Années d'expérience en intelligence artificielle: 13.0
# Années d'expérience en santé: 1.0
# #####################################
# #####################################
# ID: 63
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Instituti
# Titre d'emploi: Directrice Adjointe
# Organisation d'affiliation: Polytechnique Montréal, Autre
# Autre organisation d'affiliation: Institut TransMedTech
# Expertises: Living Lab, innovation ouverte, instrument médicaux
# Années d'expérience en intelligence artificielle: 5.0
# Années d'expérience en santé: 20.0
# #####################################
# #####################################
# ID: 64
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: communaute formation IA du CHUM
# Titre d'emploi: medecin specialiste
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: INESSS
# Expertises: evaluation des technologies
# Années d'expérience en intelligence artificielle: 2.0
# Années d'expérience en santé: 35.0
# #####################################
# #####################################
# ID: 65
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: postdoctoral
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, LIO- Laboratoire de recherche en Imagerie et Orthopédie, TÉLUQ- Université TÉLUQ
# Autre organisation d'affiliation: TELUQ university
# Expertises: Machine learning, Deep learning, biomedical signal processing
# Années d'expérience en intelligence artificielle: 10.0
# Années d'expérience en santé: 5.0
# #####################################
# #####################################
# ID: 66
# Prénom: nan
# Nom: nan
# Profession: Industriels
# Autre profession: nan
# Titre d'emploi: Coordonatrice aux soins
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: Dialogue
# Expertises: J'ai complété une maîtrise en santé publique à l'Université McGill en mai 2021, et je travaille depuis dans le domaine de la télémédecine chez l'entreprise canadienne Dialogue. Je m'intéresse aux enjeux du numérique dans le réseau de la santé, ainsi qu'à l'application de l'apprentissage machine et de l'IA dans ces technologies.
#
# https://www.linkedin.com/in/liliabrahimi/
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 1.0
# #####################################
# #####################################
# ID: 67
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: Doctorante PhD student
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: The Institute of Robotics and Process Control TU Braunschweig
# Expertises: IA et robotique
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 0.0
# #####################################
# #####################################
# ID: 69
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Professionnels en informatique
# Titre d'emploi: Developpeur Fullstack
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: nan
# Expertises: Je suis développeuse et je possède un master en IA et Data science
# Années d'expérience en intelligence artificielle: 2.0
# Années d'expérience en santé: 0.0
# #####################################
# #####################################
# ID: 70
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: Ingénieur
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: CEA
# Expertises: coder
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 0.0
# #####################################
# #####################################
# ID: 71
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Professionelle Scientifique - Santé numérique
# Organisation d'affiliation: MSSS- Ministère de la Santé et des Services Sociaux
# Autre organisation d'affiliation: INESSS
# Expertises: Maitrise en santé publique, expérience 1 an en santé numérique
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 1.0
# #####################################
# #####################################
# ID: 72
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: Gestionnaire de la recherche et de l'innovation
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: Vestechpro
# Expertises: Vêtement intelligent, développement de produits complexes, ingénierie système, innovation et entreprenariat, financement de l'innovation.
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 0.0
# #####################################
# #####################################
# ID: 73
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: microprogramme de 2e cycle en gestion - technologie de l'information
# Organisation d'affiliation: UDEM- Université de Montréal
# Autre organisation d'affiliation: HEC
# Expertises: À travers mon expérience professionnelle et académique dans le domaine de la santé, j’ai développé un réel intérêt pour l’innovation, l’IA et la transformation numérique dans le but de favoriser l’optimisation des processus dans le réseau de la santé. J’ai effectué mon stage d’intégration de BAC en coordination d’activités à l’Institut de Cardiologie de Montréal où j’ai eu la chance d’observer et de contribuer à l’implantation de solutions technologiques innovantes dans le cadre de la refonte du système de santé du Québec. Ainsi, ma curiosité, ma détermination ainsi que mon désir de contribuer à un système de santé meilleur m’ont poussé à débuter un microprogramme de 2e cycle en technologie de l’information tout en travaillant comme infirmière clinicienne à l’urgence de Royal-Victoria dans l'attente de débuter un MBA par la suite. Je suis également impliquée à titre de VP- logistique dans le comité des sciences des données de HEC afin d’élargir mes connaissances et développer de nouvelles compétences.
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 2.0
# #####################################
# #####################################
# ID: 74
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Employé
# Titre d'emploi: Chargé de projet clinique Télésanté
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: CISSS-CA
# Expertises: Je m'intéresse depuis plusieurs années aux technologies en santé/réadaptation. Je lis beaucoup sur le sujet, j'ai suivi/donné plusieurs formations.  J'ai participé à l'implantation de plusieurs technologies dans les services dans lesquels j'ai travaillé (outils d'assistance, développement de chatbots, gestion d'une flotte d'iPads, outils connectés, etc)
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 15.0
# #####################################
# #####################################
# ID: 75
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: Conseiller en IA au MSSS
# Titre d'emploi: Conseiller en IA au MSSS
# Organisation d'affiliation: MSSS- Ministère de la Santé et des Services Sociaux
# Autre organisation d'affiliation: None
# Expertises: À Discuter lors d'une rencontre
# Années d'expérience en intelligence artificielle: 3.0
# Années d'expérience en santé: 2.0
# #####################################
# #####################################
# ID: 76
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Biologiste médicale
# Titre d'emploi: PhD
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: CHU DE MONTRÉAL
# Expertises: Expert en histomorphométrie osseuse et Responsable plateforme de pathologie numérique
# Années d'expérience en intelligence artificielle: 3.0
# Années d'expérience en santé: 27.0
# #####################################
# #####################################
# ID: 77
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Conseiller en innovation des technologie au MSSS
# Organisation d'affiliation: MSSS- Ministère de la Santé et des Services Sociaux
# Autre organisation d'affiliation: nan
# Expertises: Je suis ingénieur biomédical de formation. J'ai 5 années d'expérience e gestion des technologies médicales en milieu hospitalier.
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 3.0
# #####################################
# #####################################
# ID: 78
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Professionnelle scientifique en évaluation de la santé numérique
# Organisation d'affiliation: MSSS- Ministère de la Santé et des Services Sociaux, Autre
# Autre organisation d'affiliation: INESSS Institut National d'Excellence en Santé et Services Sociaux
# Expertises: Recherche en évaluation de la santé numérique, évaluation, impact et implantation IA dans le système de santé et développement d'outils et activités d'évaluation de l'impact
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 2.0
# #####################################
# #####################################
# ID: 79
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: Militaire & clinicien retraité et prochainement Post-doct.
# Titre d'emploi: Doctorant en médecine expérimentale (processus de graduation) et entrepreneur scientific
# Organisation d'affiliation: CRCHUSJ- Centre de Recherche du Centre Hospitalier de Sainte Justine, UDEM- Université de Montréal, Autre
# Autre organisation d'affiliation: Intelligence médicale CBRNE Inc. & Opération Compagnons d'armes
# Expertises: Officier de défense CBRNE Avancé avec les Forces canadiennes, officier du renseignement, officier infirmier-clinicien, inventeur, entrepreneur et pilote de drone. Les intérêts sont:  Pre-hospital interventions in contaminated environment (Mass-casualty management; Protection; Decontamination; Extraction); ii. Triage tools; iii. Automatization & Artificial Intelligence systems (Applied Technologies in emergency responses up-to conversion of existing technologies); iv. Use of drone & telemedicine applied in pre-hospital settings (including Virtual Settings); v. Respiratory protection (i.e.: respiratory physiology, aerosol, respiratory effort indexes, oxygen-therapy, respiratory assisting devices for the gas mask technology, respiratory/blood gas); vi. Fluid mechanics; vii. Security Intelligence (Weapons of mass destruction, CBRNE, Global Security, Counterintelligence & Biometric, psyops, deception); viii.  Community: social and medical problematic in homeless veterans.
# *CBRNE: Chimique, Biologique, Radiologique, Nucléaire, Explosif
# Années d'expérience en intelligence artificielle: 5.0
# Années d'expérience en santé: 26.0
# #####################################
# #####################################
# ID: 80
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: nan
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: TOPMED
# Expertises: Biomecanique, readaptation, neuroscience, locomotion
# Années d'expérience en intelligence artificielle: 0.25
# Années d'expérience en santé: 10.0
# #####################################
# #####################################
# ID: 81
# Prénom: nan
# Nom: nan
# Profession: Industriels
# Autre profession: nan
# Titre d'emploi: Senior Consultant Data Analytics
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Statistics, Machine learning, Data engineering, Python, R
# Années d'expérience en intelligence artificielle: 4.5
# Années d'expérience en santé: 2.0
# #####################################
# #####################################
# ID: 82
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Agente de planification, de programmation et de recherche
# Organisation d'affiliation: MSSS- Ministère de la Santé et des Services Sociaux
# Autre organisation d'affiliation: Centre d'expertise en intelligence artificielle et valorisation des données
# Expertises: Vigie et transfert de connaissances
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 25.0
# #####################################
# #####################################
# ID: 83
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: Professeure
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: UDS - Université de Sherbrooke
# Expertises: Intégration sémantique de données et modélisation et exploitation de bases de données temporelles
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 3.0
# #####################################
# #####################################
# ID: 84
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: Chercheurs
# Titre d'emploi: Enseignant
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: Université du Québec à Montréal
# Expertises: Doctorat en statistique
# Années d'expérience en intelligence artificielle: nan
# Années d'expérience en santé: nan
# #####################################
# #####################################
# ID: 85
# Prénom: nan
# Nom: nan
# Profession: Industriels
# Autre profession: nan
# Titre d'emploi: senior regional market access manager
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: Edwards Lifesciences, Inc. - Mississauga, ON
# Expertises: utilisation des données pour évaluation des technologies de la santé
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 25.0
# #####################################
# #####################################
# ID: 86
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: Associé de recherche
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: CR Douglas
# Expertises: Anthropologie, IA, Neuroscience
# Années d'expérience en intelligence artificielle: 3.0
# Années d'expérience en santé: 2.0
# #####################################
# #####################################
# ID: 87
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Employée générale CHUM
# Titre d'emploi: Agente
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Nulle en IA
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 20.0
# #####################################
# #####################################
# ID: 88
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: Chercheur industriel
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: Centre de Recherche Informatique de Montréal
# Expertises: Machine Learning, Process Mining, Trajectoires patients, Données médico-administratives
# Années d'expérience en intelligence artificielle: 7.0
# Années d'expérience en santé: 7.0
# #####################################
# #####################################
# ID: 89
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: Clinicienne (Obstétrique Et Gynécologie)
# Titre d'emploi: MD, MSc, professeure adjointe de clinique
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Clinicienne
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 31.0
# #####################################
# #####################################
# ID: 90
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: Doctorante
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: Université Laval
# Expertises: Technologie éducative, expérience apprentissage
# Années d'expérience en intelligence artificielle: nan
# Années d'expérience en santé: nan
# #####################################
# #####################################
# ID: 91
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: professionnel de la santé
# Titre d'emploi: Coordonnateur technique en imagerie médicale
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: CIUSSS Ouest de l'ile - Hôpital de Lasalle
# Expertises: Ayant un diplôme universitaire (DU) de l'université de Bourgogne (France) en Intelligence artificielle santé (actuellement master), j'aimerai faire partie de groupes de travail ou comités dans ce domaine pour plus d'opportunités...
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 20.0
# #####################################
# #####################################
# ID: 96
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: Étudiante en dernière année d'ingénierie informatique
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: Université de carthage
# Expertises: Python, algorithme d'intélligence artificiel
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 0.0
# #####################################
# #####################################
# ID: 97
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: Professeure agrégée
# Organisation d'affiliation: TÉLUQ- Université TÉLUQ
# Autre organisation d'affiliation: nan
# Expertises: Étude de l'adoption des objets connectés par les patients utilisateurs
# Années d'expérience en intelligence artificielle: 4.0
# Années d'expérience en santé: 4.0
# #####################################
# #####################################
# ID: 98
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: Entrepreneur
# Titre d'emploi: CEO
# Organisation d'affiliation: ÉIAS- École de l'Intelligence Artificielle en Santé
# Autre organisation d'affiliation: projet phoenix
# Expertises: Communication- Démocratisation- UI design
# Années d'expérience en intelligence artificielle: 3.0
# Années d'expérience en santé: nan
# #####################################
# #####################################
# ID: 99
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: nan
# Titre d'emploi: Néonatalogiste - Principal Investigator of NeoCardioLab - www.neocardiolab.com
# Organisation d'affiliation: CRCHUSJ- Centre de Recherche du Centre Hospitalier de Sainte Justine, Autre
# Autre organisation d'affiliation: RI-MUHC
# Expertises: Je me spécialise en échocardiographie néonatale, ainsi qu'en mesure de déformation myocardique (speckle tracking echocardiography). Je suis également épidemiologiste (MSc) et m'intéresse aux études de cohortes. J'ai un intérêt pour l'analyse de la fonction cardiaque, en période néonatale (et fétale).
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 18.0
# #####################################
# #####################################
# ID: 102
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Employé
# Titre d'emploi: Conseillère clinique
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: Étudiante à l'ÉTS en technologies de la santé
# Expertises: Je n'ai pas d'expertise dans le domaine IA. Mais j'ai travaillé en tant que professionnel de la santé et actuellement conseillère clinique en télésanté, et je m'intéresse à savoir plus sur les innovations et les nouvelles technologies
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 13.0
# #####################################
# #####################################
# ID: 104
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Bibliothécaire (j'espère que ça tombe dans Professionnelles de recherche !)
# Organisation d'affiliation: UDEM- Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: J'ai déjà assisté l'ÉIA avec quelques projets (curation de contenu pour le répertoire des formations ; une recherche documentaire sur le « readiness » pour l'IA dans le milieu clinique), et j'ai fait d'autres recherches documentaires sur l'IA en santé (apprentissage par machine, le diagnostic par algorithme en dermato). Mon expertise est donc en recherche documentaire.
# Années d'expérience en intelligence artificielle: 4.0
# Années d'expérience en santé: 5.0
# #####################################
# #####################################
# ID: 105
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: Médecin Résident
# Titre d'emploi: Médecin Résident
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal, ÉIAS- École de l'Intelligence Artificielle en Santé
# Autre organisation d'affiliation: nan
# Expertises: Programmation en python.
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 8.0
# #####################################
# #####################################
# ID: 106
# Prénom: nan
# Nom: nan
# Profession: Professionnels de recherche
# Autre profession: nan
# Titre d'emploi: Développeur IA au ministère de la santé
# Organisation d'affiliation: MSSS- Ministère de la Santé et des Services Sociaux
# Autre organisation d'affiliation: nan
# Expertises: Développeur Full Stack en IA
# Années d'expérience en intelligence artificielle: 5.0
# Années d'expérience en santé: 2.0
# #####################################
# #####################################
# ID: 107
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: Employée des services publics
# Titre d'emploi: Chercheuse indépendante; Conseillère en Intelligence Artificielle et valorisation de données
# Organisation d'affiliation: MSSS- Ministère de la Santé et des Services Sociaux
# Autre organisation d'affiliation: Éventuellement, McGill
# Expertises: Recherche appliquée pour l'opérationnalisation de l'Ia Responsable
# Années d'expérience en intelligence artificielle: 2.0
# Années d'expérience en santé: 2.0
# #####################################
# #####################################
# ID: 109
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Chef d'équipe - coordonnateur
# Titre d'emploi: Chef d'équipe - coordonnateur en IA et géomatique
# Organisation d'affiliation: MSSS- Ministère de la Santé et des Services Sociaux
# Autre organisation d'affiliation: Direction de l’analyse et de l’intelligence artificielle - Direction générale de la planification stratégique et de la performance (DGPSP)
# Expertises: Sciences des données
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 1.0
# #####################################
# #####################################
# ID: 110
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: nan
# Organisation d'affiliation: MSSS- Ministère de la Santé et des Services Sociaux
# Autre organisation d'affiliation: nan
# Expertises: Dans le domaine de l'IA j'ai eu à manipuler les algorithmes de classifications et de NLP pendant mes études et dans le cadre de mon travail au MSSS-DAIA
# Années d'expérience en intelligence artificielle: 4.0
# Années d'expérience en santé: 1.0
# #####################################
# #####################################
# ID: 111
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: professionnel de santé
# Titre d'emploi: etudiant professionnel
# Organisation d'affiliation: Autre
# Autre organisation d'affiliation: ministere de la santé
# Expertises: infirmier anesthesiste master gestion de projet- master e santé
# Années d'expérience en intelligence artificielle: 2.0
# Années d'expérience en santé: 18.0
# #####################################
# #####################################
# ID: 112
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: nan
# Titre d'emploi: Agent de programmation, planification et recherche
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: ADEAC CHUM
# Expertises: Conseillance pédagogique - intégration des compétences en IA santé
# Années d'expérience en intelligence artificielle: 0.5
# Années d'expérience en santé: 0.5
# #####################################
# #####################################
# ID: 114
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Agente d'amélioration continue
# Titre d'emploi: Agente de planification, de programmation et de recherche
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Doctorat en médecine, maîtrise en administration des services de santé, certificat de LeanSix Sigma (ceinture verte) et en gestion de projet
# Onze ans d'expérience en domaine de la santé et des services sociaux, dont 7 ans en
# gestion notamment en gestion de projet (5 ans)
# Coordination et gestion de projets innovants
# Optimisation et amélioration de processus et procédures dans le domaine de la santé
# Gestion des équipes multidisciplinaires
# Solide compétence d’analyse, de synthèse et de résolution de problème axée vers les
# résultats innovants
# Excellente connaissance du processus, de différents modèles d’évaluation de performance
# et de la gestion intégrée de la performance et de la qualité (Trois niveaux de la salle de
# pilotage)
# Très bonne capacité à entretenir des relations constructives avec les partenaires internes
# et externes et à favoriser la mobilisation autour de projets partagés, esprit d’équipe,
# leadership, autonomie, savoir adapter au changement, sens de l’organisation
#  Microsoft Office, Planner, Forms, Lists, Visio, Smartsheet, ACCESS, Lime Survey
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 11.0
# #####################################
# #####################################
# ID: 115
# Prénom: nan
# Nom: nan
# Profession: Autre
# Autre profession: Employé du CHUM
# Titre d'emploi: APPR
# Organisation d'affiliation: CHUM- Centre Hospitalier de l'Université de Montréal
# Autre organisation d'affiliation: CHUM
# Expertises: Conseiller pédagogique au CHUM ayant les responsabilités d'accompagner la communauté de pratique
# Années d'expérience en intelligence artificielle: 3.0
# Années d'expérience en santé: 1.0
# #####################################
# #####################################
# ID: 116
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: Médecin résident
# Titre d'emploi: Médecin résident
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, CHUM- Centre Hospitalier de l'Université de Montréal, ÉIAS- École de l'Intelligence Artificielle en Santé
# Autre organisation d'affiliation: nan
# Expertises: AutoML et ChatGPT
# Années d'expérience en intelligence artificielle: 2.0
# Années d'expérience en santé: 9.0
# #####################################
# #####################################
# ID: 117
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: Chercheur, Professionnel de santé
# Titre d'emploi: Etudiant en maîtrise (sciences médicales, option médecine computationnelle), étudiant-chercheur et agent de recherche
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, UDEM- Université de Montréal
# Autre organisation d'affiliation: nan
# Expertises: Docteur en médecine (Lauréat de l'université Med V de Rabat), Maîtrise en médecine computationnelle, sciences médicales (cours en IA), travaille sur quelques projets de recherche sous la supervision de mon directeur de recherche
# Années d'expérience en intelligence artificielle: 1.5
# Années d'expérience en santé: 8.0
# #####################################
# #####################################
# ID: 118
# Prénom: nan
# Nom: nan
# Profession: Étudiants
# Autre profession: nan
# Titre d'emploi: Étudiant baccalauréat
# Organisation d'affiliation: Polytechnique Montréal
# Autre organisation d'affiliation: nan
# Expertises: Développement logiciel
# Années d'expérience en intelligence artificielle: 1.0
# Années d'expérience en santé: 3.0
# #####################################
# #####################################
# ID: 119
# Prénom: nan
# Nom: nan
# Profession: Chercheurs
# Autre profession: Médecin Endocrinologue
# Titre d'emploi: Chercheur régulier, axe cardiométabolique
# Organisation d'affiliation: CRCHUM- Centre de recherche du centre hospitalier de l'Université de Montréal, CHUM- Centre Hospitalier de l'Université de Montréal, UDEM- Université de Montréal
# Autre organisation d'affiliation: Membre Conseil Professionnel de Diabète Québec
# Expertises: Je suis chercheuse clinicienne qui s'intéresse à la question de l'hétérogénéité du diabète; mon programme de recherche vise à mieux comprendre les formes plus atypiques et rares de diabète tel que le LADA (diabète autoimmune latent chez l'adulte), et d'identifier les sous types de diabète autoimmun (dont le LADA) à travers des cohortes et biobanques en cours de développement et en ayant recours à l'intelligence artificielle.
# Années d'expérience en intelligence artificielle: 0.0
# Années d'expérience en santé: 15.0
# #####################################

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !pip3 uninstall googletrans
# !pip3 install googletrans==3.1.0a0
# Out:
# WARNING: Skipping googletrans as it is not installed.
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==3.1.0a0)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2023.7.22)
# Collecting hstspreload (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hstspreload-2023.1.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.0)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 8.8 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.1 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.2 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.7 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.0 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16352 sha256=e2224407091558b70a12e545c444204f9aec35bdc35f5461499417177e436ff9
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
# Successfully installed chardet-3.0.4 googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2023.1.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
#Translate expertises
from googletrans import Translator
translator = Translator()
translations = translator.translate(expertises, dest="en")
expertises = [translation.text for translation in translations]

# %%
#create embeddings and store them
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
db = Chroma.from_texts(expertises, embeddings)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
SYSTEM_PROMPT = """Use the following pieces of context to answer the question at the end.
If you don't know the answer, just say that you don't know, don't try to make up an answer."""

B_INST, E_INST = "[INST]", "[/INST]"
B_SYS, E_SYS = "<>\n", "\n<>\n\n"

SYSTEM_PROMPT = B_SYS + SYSTEM_PROMPT + E_SYS

instruction = """
{context}

Question: {question}
"""

template = B_INST + SYSTEM_PROMPT + instruction + E_INST
prompt = PromptTemplate(template=template, input_variables=["context", "question"])

# %%
#Set tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf", use_auth_token=True,)

model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-chat-hf",
                                             device_map='auto',
                                             torch_dtype=torch.float16,
                                             use_auth_token=True,
                                             load_in_8bit=True
                                             )
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
#Set pipeline
pipe = pipeline("text-generation",
                model=model,
                tokenizer= tokenizer,
                torch_dtype=torch.bfloat16,
                device_map="auto",
                max_new_tokens = 1000,
                do_sample=True,
                top_k=30,
                num_return_sequences=1,
                eos_token_id=tokenizer.eos_token_id
                )
llm=HuggingFacePipeline(pipeline=pipe, model_kwargs={'temperature':0.1})

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=db.as_retriever(search_kwargs={"k": 4}),
    return_source_documents=True,
    chain_type_kwargs={"prompt": prompt},
)

# %%
result = qa_chain("I am working on a brain imaging health project and I need a web application as well as artificial intelligence capable of detecting brain tumors, suggest some experts to me.")

# %%
result['result']
# Out:
# "  Based on the provided information, the following experts in the field of brain imaging and artificial intelligence may be suitable candidates to suggest for your project:\n1. ID: 23 - With 1.0 years of experience in artificial intelligence and 6.0 years of healthcare experience, this expert has a strong background in medical imaging and AI. Their expertise is centered on classification and segmentation, which could be beneficial for brain imaging applications.\n2. ID: 91 - This expert has a university degree in Artificial Intelligence health and currently works as a technical coordinator in medical imaging. They have 1.0 years of experience in artificial intelligence and 20.0 years of healthcare experience, which could be valuable for a brain imaging project.\n3. ID: 99 - As a neonatologist and principal investigator of NeoCardioLab, this expert specializes in neonatal echocardiography and measuring myocardial deformation. They also have an interest in the analysis of cardiac function, which could be relevant for brain imaging. Although they have no direct experience in artificial intelligence, their expertise in cardiology could provide valuable insights.\n4. ID: 37 - With a master's degree in computer science and specializing in pattern recognition and artificial intelligence, this expert has 3.0 years of experience in artificial intelligence and 5.0 years of healthcare experience. They have been working on deep learning methods for almost a year, which could be beneficial for brain imaging applications.\nConsidering the specific requirements of your project, you may want to reach out to these experts to discuss their availability and interest in collaborating. However, please note that I don't know any of these individuals personally, and it's important to conduct your own research and due diligence when selecting experts for your project."

# %%
result['source_documents']
# Out:
# [Document(page_content='ID: 23\nFirst name: nah\nName: nah\nProfession: Researchers\nOther profession: no\nJob title: postdoctoral fellow\nAffiliation organization: LIO- Imaging and Orthopedics Research Laboratory\nOther affiliate organization: no\nExpertise: I have been working in AI for several months. My projects and areas of application are centered on medical imaging (classification, segmentation).\nYears of experience in artificial intelligence: 1.0\nYears of healthcare experience: 6.0', metadata={}),
#  Document(page_content='ID: 91\nFirst name: nah\nName: nah\nProfession: Other\nOther profession: healthcare professional\nJob title: Technical coordinator in medical imaging\nAffiliation Organization: Other\nOther affiliation organization: CIUSSS West Island - Lasalle Hospital\nExpertise: Having a university degree (DU) from the University of Burgundy (France) in Artificial Intelligence health (currently master), I would like to be part of working groups or committees in this field for more opportunities...\nYears of experience in artificial intelligence: 1.0\nYears of healthcare experience: 20.0', metadata={}),
#  Document(page_content='ID: 99\nFirst name: nah\nName: nah\nProfession: Researchers\nOther profession: no\nJob title: Neonatologist - Principal Investigator of NeoCardioLab - www.neocardiolab.com\nAffiliation organization: CRCHUSJ- Research Center of the Sainte Justine Hospital Center, Other\nOther Affiliation Organization: RI-MUHC\nExpertise: I specialize in neonatal echocardiography, as well as in measuring myocardial deformation (speckle tracking echocardiography). I am also an epidemiologist (MSc) and am interested in cohort studies. I have an interest in the analysis of cardiac function, in the neonatal (and fetal) period.\nYears of experience in artificial intelligence: 0.0\nYears of healthcare experience: 18.0', metadata={}),
#  Document(page_content="ID: 37\nFirst name: nah\nName: nah\nProfession: Students\nOther profession: no\nJob Title: Phd\nAffiliation organization: LIO- Imaging and Orthopedics Research Laboratory, ÉTS- School of Higher Technology\nOther affiliate organization: no\nExpertise: Master's degree in computer science, specializing in pattern recognition and artificial intelligence.\nDoctoral subject: Calibration of a stereoradiography system. EOS image classification. I have been working on deep learning methods for almost a year.\nYears of experience in artificial intelligence: 3.0\nYears of healthcare experience: 5.0", metadata={})]
